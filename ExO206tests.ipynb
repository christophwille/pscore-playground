// %% [markdown]
// Check installed version of ExchangeOnlineManagement module:

// %%
Import-Module ExchangeOnlineManagement; Get-Module ExchangeOnlineManagement
// Out:
// ModuleType Version    PreRelease Name                                ExportedCommands
// ---------- -------    ---------- ----                                ----------------
// Script     2.0.6      Preview3   ExchangeOnlineManagement            {Get-EXOCasMailbox, Get-EXOMa…

// %% [markdown]
// Connect to Exchange:

// %%
Connect-ExchangeOnline -Device
// Out:
// ----------------------------------------------------------------------------------------
// This version of EXO PowerShell V2 module contains new REST API backed cmdlets which doesn't require Windows Remote PowerShell for client-server communication.
//
// You can now run those cmdlets after turning off WinRM Basic Auth in your client machine and thus making it more secure. Read more here - https://aka.ms/exov2-securemode
//
// You can share your feedback and suggestions to exocmdletpreview@service.microsoft.com
// ----------------------------------------------------------------------------------------
//
// To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code XYZ to authenticate.

// %% [markdown]
// Viewing the list of updated cmdlets:

// %%
# https://techcommunity.microsoft.com/t5/exchange-team-blog/exchange-online-powershell-v2-module-preview-now-more-secure/ba-p/2922946
Get-Command -Module tmpEXO*
// Out:
// CommandType     Name                                               Version    Source
// -----------     ----                                               -------    ------
// Function        Add-ATPEvaluation                                  0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-AvailabilityAddressSpace                       0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-DistributionGroupMember                        0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-MailboxFolderPermission                        0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-MailboxPermission                              0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-ManagementRoleEntry                            0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-PublicFolderClientPermission                   0.0.1      tmpEXO_jmm1e3uh.cqa
// Function        Add-RecipientPermission                            0.0.1      tmpEXO_jmm1e3uh.cqa
// ...

// %%
Disconnect-ExchangeOnline
// Out:
// Running this cmdlet clears all active sessions created using Connect-ExchangeOnline or Connect-IPPSSession.
// Press(Y/y/A/a) if you want to continue.
// [Y] Yes  [A] Yes to All  [N] No  [L] No to All  [S] Suspend  [?] Help(default is 'Y')True
// Disconnected successfully !
